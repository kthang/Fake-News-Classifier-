# %% [markdown]
# # Fake _Fake_ News?: The Scraper
# Kevin Chang, Hariz Hisham, Thuy Le, Tam Nguyen, Qing Zhang<br>
# Santa Clara University

# %% [markdown]
# The goal of this exercise is to determine whether fake news and factual news sites can be told apart by contemporary algorithms.
#
# This analysis is an extension of prior [research](https://arxiv.org/abs/1810.01765) conducted at MIT. The data for this research can be retrieved [here](https://github.com/ramybaly/News-Media-Reliability/). Additionally, this project was inspired by [prior work](http://web.stanford.edu/~mattm401/docs/2018-Golbeck-WebSci-FakeNewsVsSatire.pdf) done by Golbeck et al (2018).
#
# Note: In this analysis, we are relying 100% on the output of the algorithm to determine if a news site is 'fake news' or 'reall'. We provide a caveat and explanation as to why this approach may not be completely sound (or in fact, safe) IRL.
#
# This project was done in part as a collective effort with the Markkula Center for Applied Ethics at Santa Clara University. For more information on the great work covered by the Markkula Center, click [here](https://www.scu.edu/ethics/).
#
# Special thanks to Sanjiv Das and Subbu Vincent for their support and guidance on this project.
#
# Keywords: Fake news, classification, support vector machine

# %%
import pandas as pd
import numpy as np

# %%
### DON'T RUN UNLESS ON GOOGLE COLAB ###
from google.colab import drive
drive.mount('/content/drive')
### DON'T RUN ###
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ### Read in list of news sources

# %% [markdown]
# List of sources retrieved from and generated by MIT

# %%
# Read in MIT corpus
corp = pd.read_csv('/content/drive/Shared drives/Machine Learning Project/Final Project/data/Master/data/corpus.csv',
                   index_col = False)

# %% [markdown]
# ### Perform feature renaming and merging to corpus in one block

# %%
# Define list of filenames we want loaded in
ls = ['alexa', 'counts', 'created_at', 'description', 'handcrafted_url',\
     'has_location', 'has_twitter', 'has_wiki', 'title', 'url_match', 'verified',\
     'wikicategories', 'wikicontent', 'wikisummary', 'wikitoc']

for x in ls:
    f = str(x)
    fp = '/content/drive/Shared drives/Machine Learning Project/Final Project/data/Master/data/features/' + f + '.csv'
    feat = pd.read_csv(fp, index_col = False).drop(columns = ['fact', 'bias'])
    feat.columns = [f + '_' + str(col) for col in feat.columns]
    meep = f + '_source_url_processed'
    feat = feat.rename(columns={meep:'source_url_processed'})
    corp = pd.merge(corp, feat, how = 'left', on = 'source_url_processed')

# Quick visual check
corp.sample(3)
# Out:
#                              source_url  ... wikitoc_f299
# 159  http://www.peninsuladailynews.com/  ...     0.000000
# 56          https://www.propublica.org/  ...     0.009946
# 417              http://www.fairus.org/  ...     0.058980
#
# [3 rows x 1671 columns]

# %% [markdown]
# ### Newspaper

# %% [markdown]
# We utilize the [newspaper3k package](https://buildmedia.readthedocs.org/media/pdf/newspaper/latest/newspaper.pdf) to scrape news articles listed on our corpus.

# %%
# !pip install newspaper3k
# Out:
# Collecting newspaper3k
#   Downloading https://files.pythonhosted.org/packages/d7/b9/51afecb35bb61b188a4b44868001de348a0e8134b4dfa00ffc191567c4b9/newspaper3k-0.2.8-py3-none-any.whl (211kB)
#      |████████████████████████████████| 215kB 5.0MB/s
# Collecting cssselect>=0.9.2
#   Downloading https://files.pythonhosted.org/packages/3b/d4/3b5c17f00cce85b9a1e6f91096e1cc8e8ede2e1be8e96b87ce1ed09e92c5/cssselect-1.1.0-py2.py3-none-any.whl
# Collecting feedparser>=5.2.1
#   Downloading https://files.pythonhosted.org/packages/91/d8/7d37fec71ff7c9dbcdd80d2b48bcdd86d6af502156fc93846fb0102cb2c4/feedparser-5.2.1.tar.bz2 (192kB)
#      |████████████████████████████████| 194kB 48.3MB/s
# Collecting jieba3k>=0.35.1
#   Downloading https://files.pythonhosted.org/packages/a9/cb/2c8332bcdc14d33b0bedd18ae0a4981a069c3513e445120da3c3f23a8aaa/jieba3k-0.35.1.zip (7.4MB)
#      |████████████████████████████████| 7.4MB 25.8MB/s
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.6/dist-packages (from newspaper3k) (4.6.3)
# Collecting tldextract>=2.0.1
#   Downloading https://files.pythonhosted.org/packages/fd/0e/9ab599d6e78f0340bb1d1e28ddeacb38c8bb7f91a1b0eae9a24e9603782f/tldextract-2.2.2-py2.py3-none-any.whl (48kB)
#      |████████████████████████████████| 51kB 6.6MB/s
# Requirement already satisfied: lxml>=3.6.0 in /usr/local/lib/python3.6/dist-packages (from newspaper3k) (4.2.6)
# Collecting tinysegmenter==0.3
#   Downloading https://files.pythonhosted.org/packages/17/82/86982e4b6d16e4febc79c2a1d68ee3b707e8a020c5d2bc4af8052d0f136a/tinysegmenter-0.3.tar.gz
# Requirement already satisfied: PyYAML>=3.11 in /usr/local/lib/python3.6/dist-packages (from newspaper3k) (3.13)
# Collecting feedfinder2>=0.0.4
#   Downloading https://files.pythonhosted.org/packages/35/82/1251fefec3bb4b03fd966c7e7f7a41c9fc2bb00d823a34c13f847fd61406/feedfinder2-0.0.4.tar.gz
# Requirement already satisfied: nltk>=3.2.1 in /usr/local/lib/python3.6/dist-packages (from newspaper3k) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.6/dist-packages (from newspaper3k) (2.6.1)
# Requirement already satisfied: Pillow>=3.3.0 in /usr/local/lib/python3.6/dist-packages (from newspaper3k) (4.3.0)
# Requirement already satisfied: requests>=2.10.0 in /usr/local/lib/python3.6/dist-packages (from newspaper3k) (2.21.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from tldextract>=2.0.1->newspaper3k) (42.0.2)
# Requirement already satisfied: idna in /usr/local/lib/python3.6/dist-packages (from tldextract>=2.0.1->newspaper3k) (2.8)
# Collecting requests-file>=1.4
#   Downloading https://files.pythonhosted.org/packages/23/9c/6e63c23c39e53d3df41c77a3d05a49a42c4e1383a6d2a5e3233161b89dbf/requests_file-1.4.3-py2.py3-none-any.whl
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from feedfinder2>=0.0.4->newspaper3k) (1.12.0)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from Pillow>=3.3.0->newspaper3k) (0.46)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.10.0->newspaper3k) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.10.0->newspaper3k) (2019.11.28)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.10.0->newspaper3k) (1.24.3)
# Building wheels for collected packages: feedparser, jieba3k, tinysegmenter, feedfinder2
#   Building wheel for feedparser (setup.py) ... done
#   Created wheel for feedparser: filename=feedparser-5.2.1-cp36-none-any.whl size=44940 sha256=330e7f4faefde78113bfb486cbc3e3dd7292ef6be70d29178fa6997a71bb166a
#   Stored in directory: /root/.cache/pip/wheels/8c/69/b7/f52763c41c5471df57703a0ef718a32a5e81ee35dcf6d4f97f
#   Building wheel for jieba3k (setup.py) ... done
#   Created wheel for jieba3k: filename=jieba3k-0.35.1-cp36-none-any.whl size=7398407 sha256=ba232dceabf886f91e733161e953c8d6756af475031a248a9360615c741bfdcc
#   Stored in directory: /root/.cache/pip/wheels/83/15/9c/a3f1f67e7f7181170ad37d32e503c35da20627c013f438ed34
#   Building wheel for tinysegmenter (setup.py) ... done
#   Created wheel for tinysegmenter: filename=tinysegmenter-0.3-cp36-none-any.whl size=13538 sha256=9319a3bc35f63c8a4518f9a7f58cc5ade49c84506617a029546f64d2817e8f31
#   Stored in directory: /root/.cache/pip/wheels/81/2b/43/a02ede72324dd40cdd7ca53aad718c7710628e91b8b0dc0f02
#   Building wheel for feedfinder2 (setup.py) ... done
#   Created wheel for feedfinder2: filename=feedfinder2-0.0.4-cp36-none-any.whl size=3356 sha256=cfc26abc59b2bb531572d9c9117082e5045105556d36e76e33f1f174bed84b5e
#   Stored in directory: /root/.cache/pip/wheels/de/03/ca/778e3a7a627e3d98836cc890e7cb40c7575424cfd3340f40ed
# Successfully built feedparser jieba3k tinysegmenter feedfinder2
# Installing collected packages: cssselect, feedparser, jieba3k, requests-file, tldextract, tinysegmenter, feedfinder2, newspaper3k
# Successfully installed cssselect-1.1.0 feedfinder2-0.0.4 feedparser-5.2.1 jieba3k-0.35.1 newspaper3k-0.2.8 requests-file-1.4.3 tinysegmenter-0.3 tldextract-2.2.2

# %%
from newspaper import Article
import newspaper

# %%
# Instantiate function to scrape news articles
# The scraper skips the first article (which is often empty or promotional)
# and scrapes up to 5 articles
def download_text(url):
  
  site = newspaper.build(url)
  
  ls = []

  try:
    print(url)
    
    for i in range(1, 6):

        article = site.articles[i]

        article.download()
        article.html
        article.parse()

        p = article.text
        
        ls.append(p)
        
    return np.array(ls)
        
  except:
    print(url + ' cannot be scraped.')

# %%
corp['article_raw'] = corp.source_url.apply(download_text)
# Out:
# http://www.villagevoice.com/
# https://insideclimatenews.org/
# http://www.fury.news/
# http://www.fury.news/ cannot be scraped.
# http://now8news.com/
# http://constitution.com/
# http://freebeacon.com/
# http://brexitcentral.com
# http://foreignpolicynews.org
# https://patriotpost.us/
# http://loser.com
# http://www.empiresports.co/
# http://www.emirates247.com/
# http://samuel-warde.com/
# http://www.trueactivist.com/
# https://popularresistance.org/
# https://www.thebeaverton.com/
# http://nationalreport.net/
# https://politicalmayhem.news
# http://www.itv.com/news/
# http://www.breitbart.com/
# http://www.forwardprogressives.com/
# http://www.forwardprogressives.com/ cannot be scraped.
# https://triggerreset.net
# https://www.theatlantic.com/
# http://www.dcclothesline.com/
# http://liberaldarkness.com/
# http://leftoverrights.com/
# http://inthesetimes.com/
# http://www.tampabay.com/
# http://france24-tv.com/
# http://france24-tv.com/ cannot be scraped.
# http://freewestmedia.com/
# https://theguardiansofdemocracy.com/
# http://www.darientimes.com/
# https://www.conservativeoutfitters.com/blogs/news
# https://www.conservativeoutfitters.com/blogs/news cannot be scraped.
# http://www.republicworld.com/
# http://www.timesheadline.com
# http://www.amazingnews.net/
# http://www.amazingnews.net/ cannot be scraped.
# https://www.thestar.com/
# https://aceflashman.wordpress.com/
# http://www.hoax-slayer.com/
# https://home.nra.org/
# https://americanbridgepac.org/
# https://americanbridgepac.org/ cannot be scraped.
# http://www.orlandosentinel.com/
# http://www.voanews.com/
# https://newsandstoriesfromusa.com/
# https://newsandstoriesfromusa.com/ cannot be scraped.
# http://offendedamerica.com/
# http://offendedamerica.com/ cannot be scraped.
# http://www.calgarysun.com/
# https://southafricatoday.net
# http://blackpigeonspeaks.com/
# http://blackpigeonspeaks.com/ cannot be scraped.
# https://www.churchmilitant.com/
# http://www.liberalamerica.org/
# https://www.newscientist.com/
# http://www.theskimm.com/
# https://iowastartingline.com
# http://deepleftfield.info/
# http://www.burrardstreetjournal.com/
# http://www.burrardstreetjournal.com/ cannot be scraped.
# http://www.who.int/en/
# https://www.propublica.org/
# http://yellowhammernews.com/
# http://news.groopspeak.com/
# http://news.groopspeak.com/ cannot be scraped.
# http://www.fairvote.org/
# http://www.intellectualtakeout.org/
# http://conservativefighters.com/
# http://oilprice.com/
# http://www.the-american-interest.com/
# https://gawken.com/
# https://gawken.com/ cannot be scraped.
# http://bigleaguepolitics.com/
# http://www.azcentral.com/
# http://www.leftsideofhistory.com/
# http://reagancoalition.com/
# http://monthlyreview.org/
# https://newswars.com/
# http://www.progressive.org/
# https://www.oathkeepers.org
# http://www.anthropocenemagazine.org/
# http://www.atlbanana.com/
# http://www.salon.com/
# http://www.bluestemprairie.com/
# https://brokenworldnews.com/
# https://brokenworldnews.com/ cannot be scraped.
# http://www.atimes.com/
# http://www.patriotfires.com/
# http://www.allgov.com
# http://www.thegoldwater.com/
# http://www.thegoldwater.com/ cannot be scraped.
# https://lynx.media/
# https://lynx.media/ cannot be scraped.
# http://resistancereport.com/
# http://resistancereport.com/ cannot be scraped.
# http://democraticreview.com/
# http://democraticreview.com/ cannot be scraped.
# http://www.medicaldaily.com/
# http://americannewsx.com/
# http://americannewsx.com/ cannot be scraped.
# http://www.ibtimes.com/
# https://www.japantimes.co.jp/
# http://www.chicksontheright.com/
# https://www.foreignpolicyjournal.com
# https://www.quantamagazine.org/
# https://www.buzzfeed.com/
# http://harvardpolitics.com/
# http://newsuptoday.com/
# http://newsuptoday.com/ cannot be scraped.
# https://sciencetrends.com
# https://viralcords.com/
# http://www.climatecentral.org/
# http://siouxcityjournal.com/
# https://www.commentarymagazine.com/
# https://www.commentarymagazine.com/ cannot be scraped.
# https://www.themaven.net/beingliberal
# https://www.themaven.net/beingliberal cannot be scraped.
# https://www.cpj.org/
# http://www.adelaidenow.com.au/
# http://www.epi.org/
# http://www.atlanticmedia.com/
# http://www.bangkokpost.com/
# http://bigamericannews.com/
# http://www.psypost.org/
# http://www.beliefnet.com
# https://placesjournal.org/
# http://www.politicalgarbagechute.com/
# http://www.politicalgarbagechute.com/ cannot be scraped.
# https://rewire.news/
# https://www.defconwarningsystem.com
# http://www.pnas.org/
# https://www.truthexaminer.com/
# https://www.truthexaminer.com/ cannot be scraped.
# http://www.aljazeera.com/
# https://milo.yiannopoulos.net/
# https://milo.yiannopoulos.net/ cannot be scraped.
# http://magicvalley.com/
# http://www.skeptic.com/
# http://www.marketwatch.com/
# http://abriluno.com/
# http://abriluno.com/ cannot be scraped.
# http://www.detroitnews.com/
# http://thechronicleherald.ca/
# http://theduran.com/
# https://www.teaparty.org/
# http://www.frc.org
# http://stocksnewsdaily.com/
# http://stocksnewsdaily.com/ cannot be scraped.
# http://retractionwatch.com/
# https://uawire.org/
# https://photographyisnotacrime.com/
# https://photographyisnotacrime.com/ cannot be scraped.
# http://babylonbee.com/
# http://www.polygraph.info/
# http://conservativebyte.com
# http://conservativebyte.com cannot be scraped.
# https://fas.org/
# http://www.al-monitor.com/pulse/home.html
# http://secondnexus.com/
# http://www.nwitimes.com
# http://www.morningstaronline.co.uk/
# https://www.climaterealityproject.org/
# http://theproudliberal.org/
# http://theproudliberal.org/ cannot be scraped.
# https://www.nccivitas.org/
# http://www.vox.com/
# http://freedumjunkshun.com/
# https://www.aol.com/
# http://www.lgbtqnation.com/
# http://www.beaware.one
# http://www.beaware.one cannot be scraped.
# http://liberalsociety.com/
# http://liberalsociety.com/ cannot be scraped.
# http://www.taxpayer.com/
# http://santamariatimes.com
# http://www.jamestown.org/
# https://bluntforcetruth.com
# http://www.independent.co.uk/us
# https://www.desmogblog.com/
# https://www.desmogblog.com/ cannot be scraped.
# https://niskanencenter.org
# https://www.scientificamerican.com/
# https://www.greenleft.org.au
# https://www.texasmonthly.com
# http://www.pravdareport.com/
# http://www.hindustantimes.com/
# http://www.peninsuladailynews.com/
# http://www.mirror.co.uk/
# http://americablog.com/
# http://bb4sp.com/
# http://firstinfreedomdaily.com/
# http://www.fresnobee.com/
# http://www.americanpatriotdaily.com/
# http://www.helsinkitimes.fi/
# http://www.pri.org/programs/globalpost
# http://www.tribunemagazine.org/
# http://www.tribunemagazine.org/ cannot be scraped.
# http://www.dailywire.com/
# http://bismarcktribune.com
# http://researchantisemitism.ca
# http://www.occupydemocrats.com
# https://www.thedailyvox.co.za/
# http://www.newbernsj.com/
# http://verafiles.org
# http://verafiles.org cannot be scraped.
# http://www.afa.net/
# http://freedomcrossroads.com/
# https://www.noozhawk.com/
# https://www.dailydems.com/
# https://www.dailydems.com/ cannot be scraped.
# http://www.crisismagazine.com/
# http://www.thenewsliteracyproject.org/
# http://www.wral.com/
# https://thesternfacts.com/
# http://truthinmedia.com/
# http://kff.org/
# https://rightwingnews.com/
# http://mediashift.org/
# https://www.thebalance.com
# http://www.christianpost.com/
# http://pogo.org/
# http://www.newswithviews.com/
# http://metro.co.uk/
# https://www.thepublicdiscourse.com/
# http://www.ocregister.com/
# https://www.taxjustice.net/
# https://www.theguardian.com/observer
# http://www.dailyprogress.com
# http://libcom.org
# http://www.zeit.de/english/index
# http://www.statesmanjournal.com/
# http://www.renewamerica.com
# http://www.eurasiagroup.net/
# http://www.shtfplan.com/
# http://www.weeklystandard.com/
# http://joeforamerica.com
# https://www.greentechmedia.com/
# https://news.cgtn.com
# https://news.cgtn.com cannot be scraped.
# https://www.opendemocracy.net/
# http://breakingdefense.com/
# https://newsbreakshere.com/
# https://newsbreakshere.com/ cannot be scraped.
# https://egyptianstreets.com/
# https://70news.wordpress.com/
# https://70news.wordpress.com/ cannot be scraped.
# http://www.poynter.org/
# http://www.addictinginfo.org/
# http://www.surenews.com/
# http://www.janes.com/
# https://www.nova-magazine.net
# https://www.nova-magazine.net cannot be scraped.
# https://thewest.com.au/
# http://usaconservativereport.com
# http://usaconservativereport.com cannot be scraped.
# http://www.express.co.uk/
# http://www.postbulletin.com/
# http://www.oilandwaterdontmix.org/
# http://iwf.org/
# https://newmoderate.com/
# http://www.ips-dc.org
# http://www.heritage.org/
# http://www.americanheritage.com
# http://www.westmonster.com/
# http://www.westmonster.com/ cannot be scraped.
# http://www.phnompenhpost.com/
# http://fair.org/
# https://redice.tv/
# http://www.timesofisrael.com/
# http://www.newsmax.com/
# http://www.rstreet.org/
# http://www.thepostemail.com/
# http://www.swedishwire.com/
# http://www.swedishwire.com/ cannot be scraped.
# http://www.diversityinc.com
# http://www.diversityinc.com cannot be scraped.
# http://pilotonline.com/
# http://www.stopfake.org/
# http://www.stopfake.org/ cannot be scraped.
# https://www.almasdarnews.com
# http://www.pgpf.org/
# http://realnewsrightnow.com/
# http://progresstribune.com/
# http://progresstribune.com/ cannot be scraped.
# http://rightweb.irc-online.org
# http://www.mlive.com/grand-rapids/#/0
# http://www.providencejournal.com/
# http://jewishbreakingnews.com
# http://www.truth-out.org/
# https://ffrf.org/
# http://www.vermontindependent.org/
# http://rapidcityjournal.com
# http://www.theonion.com/
# http://www.demos.org
# http://www.ledevoir.com/
# http://auburnpub.com/
# https://quadrant.org.au
# https://patribotics.blog/
# http://mbganews.com/
# http://mbganews.com/ cannot be scraped.
# http://politifeed.net
# https://www.bloomberg.com/
# https://www.bloomberg.com/ cannot be scraped.
# https://itsgoingdown.org/
# http://republicanssucks.org
# http://republicanssucks.org cannot be scraped.
# https://bipartisanpolicy.org
# https://antifascistnews.net/
# http://www.kentucky.com/
# http://dailysignal.com/
# http://www.courier-journal.com/
# http://vancouversun.com/
# http://www.timescolonist.com/
# https://techxplore.com/
# https://techxplore.com/ cannot be scraped.
# http://www.dailyrecord.com/
# http://www.vivaliberty.com/
# http://www.vivaliberty.com/ cannot be scraped.
# http://newsite.thehindu.com/
# http://www.scotusblog.com/
# http://www.dailynews.com/
# https://www.hcn.org
# http://www.680news.com/
# http://jezebel.com/
# http://www.takepart.com/
# http://nautil.us/
# http://triblive.com/
# http://crimeresearch.org/
# http://www.theoslotimes.com/
# http://www.theoslotimes.com/ cannot be scraped.
# http://www.euronews.com/
# http://www.pennlive.com/
# http://toprightnews.com
# http://toprightnews.com cannot be scraped.
# http://www.newsobserver.com/
# https://altoday.com/
# http://humanprogress.org/
# http://humanprogress.org/ cannot be scraped.
# https://conservativemedia.com/
# http://www.newsbiscuit.com/
# http://www.news24.com/
# http://www.chicagotribune.com/
# https://www.thelondoneconomic.com
# http://www.ebar.com/
# http://consmovement.com/
# http://consmovement.com/ cannot be scraped.
# http://www.youngcons.com/
# http://www.youngcons.com/ cannot be scraped.
# http://reverbpress.com/
# http://reverbpress.com/ cannot be scraped.
# http://www.therebel.media/
# http://www.therebel.media/ cannot be scraped.
# https://www.inquirer.net/
# https://thelapine.ca/
# http://newpol.org/
# http://www.economist.com/
# https://newrepublic.com/
# https://www.lifesitenews.com/
# https://www.nextbigfuture.com
# http://www.politifact.com/
# http://tennesseestar.com/
# https://www.pluralist.com
# https://www.pluralist.com cannot be scraped.
# http://sbgi.net/
# https://thefloridasqueeze.com/
# http://www.countercurrents.org/
# http://www.countercurrents.org/ cannot be scraped.
# https://newmatilda.com/
# http://www.theverge.com/
# http://www.loonwatch.com/
# https://www.dawn.com/
# http://everydayfeminism.com/
# https://www.weforum.org/
# https://www.thereligionofpeace.com/
# https://voiceofeurope.com/
# https://www.aclu.org/
# http://legalinsurrection.com/
# http://poststar.com
# https://www.eff.org/
# http://www.nationalcenter.org/
# http://bluenationreview.com/
# http://bluenationreview.com/ cannot be scraped.
# http://www.realclearpolitics.com/
# https://thebaffler.com/
# http://www.presstv.com/
# http://www.hoggwatch.com
# http://lethbridgeherald.com/
# http://www.valleynewslive.com/
# http://highline.huffingtonpost.com
# http://crosscut.com/
# https://yesimright.com/
# http://vidmax.com/
# https://world.wng.org/
# https://www.thecipherbrief.com/
# http://www.codepink.org/
# http://www.codepink.org/ cannot be scraped.
# https://www.leftscoop.com/
# https://www.leftscoop.com/ cannot be scraped.
# http://www.sltrib.com/
# http://ipatriot.com
# http://www.news-gazette.com/
# https://studionewsnetwork.com
# http://www.mcall.com
# http://conservativetribune.com/
# http://conservativetribune.com/ cannot be scraped.
# http://www.dailysabah.com/
# https://www.oneindia.com/
# http://newsthump.com/
# https://bullshitnews.org/
# https://ncse.com/
# https://renewedright.com
# https://www.transparency.org/
# https://www.adaa.org/
# http://www.alternet.org/
# http://www.puppetstringnews.com/
# https://calwatchdog.com
# http://www.sfchronicle.com/
# http://www.progressivestoday.com/
# http://projectcensored.org/
# http://billmoyers.com/
# https://www.fastcompany.com/
# http://www.dailysquib.co.uk/
# http://www.citypaper.com/
# https://www.jihadwatch.org/
# http://thepeoplestruth.com/
# http://thepeoplestruth.com/ cannot be scraped.
# http://www.financialexpress.com/
# https://conservativedailypost.com/
# http://www.smirkingchimp.com/
# http://www.pacificresearch.org/home/
# http://truthbetold.news/
# http://thepeoplescube.com
# http://thepeoplescube.com cannot be scraped.
# http://patrioticviralnews.com/
# http://patrioticviralnews.com/ cannot be scraped.
# http://www.thenewcivilrightsmovement.com/
# http://www.bipartisanreport.com/
# http://www.viralthread.com/
# http://www.viralthread.com/ cannot be scraped.
# https://concernedwomen.org/blog/
# http://thehardtimes.net/
# http://trib.com
# https://ntknetwork.com
# https://ntknetwork.com cannot be scraped.
# http://www.thatsnonsense.com/
# http://www.denverpost.com/
# http://www.telesurtv.net/english/
# http://www.telesurtv.net/english/ cannot be scraped.
# http://www.metro.us/
# http://www.npr.org/sections/news/
# https://judicialnetwork.com/
# https://judicialnetwork.com/ cannot be scraped.
# http://www.dailykos.com/
# http://speisa.com/
# http://speisa.com/ cannot be scraped.
# http://montrealgazette.com/
# https://www.thequint.com/
# http://outlook.monmouth.edu/
# https://aclj.org/
# http://elpais.com/elpais/inenglish.html
# https://tytnetwork.com/
# https://www.geneticliteracyproject.org/
# https://nowthisnews.com/
# http://www.againstcronycapitalism.org/
# http://www.againstcronycapitalism.org/ cannot be scraped.
# http://gotnews.com/
# http://gotnews.com/ cannot be scraped.
# http://other98.com/
# http://thinkprogress.org/
# http://personalliberty.com/
# http://www.star-telegram.com/
# http://www.trumpservativenews.info
# http://www.trumpservativenews.info cannot be scraped.
# http://viraldevil.com
# http://viraldevil.com cannot be scraped.
# http://www.votevets.org/
# http://www.bizpacreview.com/
# http://www.usatoday.com/
# https://thehornnews.com/
# https://colombiareports.com
# http://www.focusonthefamily.com/
# http://heavy.com/
# http://rightalerts.com/
# http://rightalerts.com/ cannot be scraped.
# http://www.allthatsfab.com/
# http://www.allthatsfab.com/ cannot be scraped.
# http://www.globetoday.com/
# http://www.globetoday.com/ cannot be scraped.
# http://fortnightlyreview.co.uk/
# http://prospect.org/
# http://www.fairus.org/
# http://www.judicialwatch.org/
# http://www.sfgate.com/
# http://www.businessinsider.com/
# http://deepstatenation.com
# http://deepstatenation.com cannot be scraped.
# http://ir.net/
# http://elitedaily.com/
# http://www.chroniclesofdemocracy.com/
# http://mtstandard.com
# http://www.esquire.com/
# http://takimag.com/
# https://squawker.org/
# https://squawker.org/ cannot be scraped.
# https://www.americanewshub.com
# https://www.americanewshub.com cannot be scraped.
# https://morningconsult.com/
# http://www.carbonated.tv/
# http://www.carbonated.tv/ cannot be scraped.
# http://pmnightlynews.com/
# http://www.gopusa.com/
# https://www.icij.org/
# http://www.9news.com.au/
# https://newint.org/
# http://www.inquisitr.com/news/
# https://www.fwweekly.com/
# https://www.consumerreports.org
# http://trueviralnews.com/
# http://politicalsitenews.com
# http://politicalsitenews.com cannot be scraped.
# http://www.dailymail.co.uk/ushome/index.html
# https://techcrunch.com
# https://www.recode.net/
# https://stepfeed.com
# http://www.thefiscaltimes.com/
# https://conservativetoday.com
# http://www.pri.org/
# http://www.pri.org/ cannot be scraped.
# http://www.syriana-analysis.com
# http://www.jordantimes.com/
# https://www.opednews.com/
# http://www.lohud.com/
# http://www.cato.org/regulation/
# http://www.clickhole.com/
# http://grist.org/
# http://www.wnd.com/
# http://www.breitbartunmasked.com/
# http://www.geologyin.com/
# https://www.progressiveliberal.net
# https://www.progressiveliberal.net cannot be scraped.
# http://www.amren.com/
# http://act.tv
# http://act.tv cannot be scraped.
# http://www.wionews.com/
# http://www.baltimoresun.com/
# https://www.adflegal.org/
# http://www.guns.com
# https://www.getreligion.org/
# http://www.webmd.com/
# https://www.chroniclesmagazine.org/
# https://www.alec.org
# http://www.nzherald.co.nz
# https://thewalrus.ca/
# http://canadafreepress.com/
# https://rantt.com
# http://www.americansforprosperity.org
# http://medicalxpress.com/
# http://medicalxpress.com/ cannot be scraped.
# http://www.jpost.com/Jerusalem-Report
# https://www.courthousenews.com
# http://chicagoreporter.com/
# https://www.aei.org/
# http://www.seattlepi.com/
# http://thehill.com/
# https://www.10news.one/
# http://www.tmn.today/
# http://www.tmn.today/ cannot be scraped.
# https://international.thenewslens.com/
# http://www.oaoa.com
# http://littlegreenfootballs.com/
# https://www.acpeds.org/
# https://o4anews.com/
# https://o4anews.com/ cannot be scraped.
# https://euobserver.com/
# http://www.washingtontimes.com/
# http://therightstuff.biz/
# https://understandrealitythroughscience.blogspot.com/
# http://tribunist.com/
# http://worldnewsdailyreport.com/
# http://economyincrisis.org/
# http://economyincrisis.org/ cannot be scraped.
# http://realtimepolitics.com/
# http://realtimepolitics.com/ cannot be scraped.
# http://en-volve.com/
# http://timesofindia.indiatimes.com/
# http://www.memeorandum.com/
# http://www.dailypresser.com/
# http://www.dailypresser.com/ cannot be scraped.
# http://indiatoday.intoday.in/
# https://www.fairobserver.com
# https://www.japantoday.com/
# https://www.thesaturdaypaper.com.au/
# http://www.hillarybeattrump.org/
# http://therightscoop.com/
# http://www.vdare.com/
# http://dailyworldinformation.com
# http://dailyworldinformation.com cannot be scraped.
# http://freedomsfinalstand.com/
# http://freedomsfinalstand.com/ cannot be scraped.
# https://www.hrw.org/
# https://stubhillnews.com/
# http://www.exposinggovernment.com
# http://www.exposinggovernment.com cannot be scraped.
# http://www.sun-sentinel.com/
# http://tucson.com/
# http://www.castanet.net/
# http://londonwebnews.com/
# http://www.thewhim.com/
# http://www.thewhim.com/ cannot be scraped.
# http://www.newstatesman.com/
# https://www.policyed.org/
# http://www.wsj.com/
# https://www.ff.org
# http://thetruthdivision.com/
# http://thetruthdivision.com/ cannot be scraped.
# http://humanevents.com/
# https://newromantimes.com/
# http://gulfnews.com/
# https://budapestbeacon.com/
# http://libertyunyielding.com/
# http://www.chinadaily.com.cn/
# https://www.migrationpolicy.org
# http://www.governing.com/
# https://www.speakgov.com/
# https://www.speakgov.com/ cannot be scraped.
# http://ladylibertysnews.com/
# http://ladylibertysnews.com/ cannot be scraped.
# http://www.foxnews.com/
# https://www.verywell.com
# http://newsheist.com/
# http://newsheist.com/ cannot be scraped.
# http://www.sungazette.com/
# http://www.euractiv.com/
# http://crooksandliars.com/
# https://leadstories.com/
# http://shareblue.com/
# https://deadspin.com/
# https://www.universitybusiness.com/
# http://conservativepost.com/
# https://clarionproject.org/
# http://napavalleyregister.com
# https://www.heartland.org/
# https://sojo.net/
# http://www.callthecops.net/
# http://truthuncensored.net/
# http://www.popularmechanics.com/
# http://www.popularmechanics.com/ cannot be scraped.
# http://www.capoliticalreview.com/
# http://www.truthdig.com/
# https://adobochronicles.com/
# https://www.timeslive.co.za/
# http://thehayride.com/
# https://toinformistoinfluence.com/
# https://herald-review.com
# http://www.glamour.com/
# https://www.insidehighered.com/
# http://www.ozy.com/
# http://www.ozy.com/ cannot be scraped.
# https://dailyworldupdate.us
# https://tdn.com
# http://www.skyandtelescope.com/
# http://frankmag.ca
# https://www.ire.org/
# https://www.ire.org/ cannot be scraped.
# http://www.thedailybeast.com/
# http://carolinapublicpress.org/
# http://progressivearmy.com
# http://democraticmoms.com/
# http://democraticmoms.com/ cannot be scraped.
# http://themoderatevoice.com/
# https://www.mnn.com
# http://www.rockcitytimes.com/
# http://en.bbarta24.net/
# http://www.irena.org
# http://www.advocate.com/
# http://biggovernment.news/index.html
# http://qpolitical.com/
# http://qpolitical.com/ cannot be scraped.
# http://www.truthrevolt.org/
# http://www.bettergov.org/
# https://americanmilitarynews.com
# https://acculturated.com
# https://acculturated.com cannot be scraped.
# http://freedomoutpost.com/
# http://theknifemedia.com/
# http://theknifemedia.com/ cannot be scraped.
# http://www.reviewjournal.com/
# http://wonkette.com/
# http://www.thegatewaypundit.com/
# http://www.thegatewaypundit.com/ cannot be scraped.
# http://www.fpri.org/
# http://madworldnews.com/
# http://conservativefiringline.com/
# http://politicops.com/
# http://www.derfmagazine.com/
# https://www.currentaffairs.org/
# http://defiantamerica.com/
# http://www.rollcall.com/
# https://teddystick.com/
# https://teddystick.com/ cannot be scraped.
# https://sandiegofreepress.org/
# http://therealnews.com/t2/
# http://www.nationofchange.org/
# https://ricochet.com
# https://ricochet.com cannot be scraped.
# http://www.citizen-times.com/
# http://waterfordwhispersnews.com/
# http://www.aim.org/
# http://www.upi.com/
# https://thevarsity.ca/
# https://thetab.com/
# http://www.shareably.net/
# http://www.saudigazette.com.sa
# http://www.opposingviews.com/
# http://listverse.com/
# http://www.theaustralian.com.au/
# http://www.oregonlive.com/#/0
# http://washingtonpress.com
# http://news.abs-cbn.com/
# http://www.hangthebankers.com/
# http://www.nationalnewswatch.com/
# http://duhprogressive.com/
# https://dutchreview.com/
# https://www.healthline.com/
# http://watchdog.org/
# http://spectator.org/
# https://www.alaraby.co.uk/english
# http://journalstar.com/
# https://this.org/
# https://www.ced.org/
# http://www.rfa.org/english/
# http://filmingcops.com/
# https://stonecoldtruth.com/
# http://spiked-online.com/
# http://meanlefthook.com/
# http://dcwhispers.com/
# http://www.plymouthpatriotpost.com/
# http://www.plymouthpatriotpost.com/ cannot be scraped.
# https://extranewsfeed.com
# http://dailycaller.com/
# https://bitchmedia.org/
# http://www.colddeadhands.us/
# http://www.colddeadhands.us/ cannot be scraped.
# http://campaignforliberty.org/
# https://remnantnewspaper.com
# https://remnantnewspaper.com cannot be scraped.
# http://guardianlv.com/
# http://unclesamsmisguidedchildren.com/
# http://unclesamsmisguidedchildren.com/ cannot be scraped.
# https://www.thewrap.com
# https://www.yahoo.com/news/?ref=gs
# http://www.cnn.com/
# https://ageofshitlords.com/
# https://ageofshitlords.com/ cannot be scraped.
# http://undergroundjournalist.org/
# http://viraltitle.com
# http://viraltitle.com cannot be scraped.
# http://www.courant.com/
# http://nottnews.com/
# http://nottnews.com/ cannot be scraped.
# http://www.lifezette.com/
# http://www.restoreamericanglory.com/
# https://mises.org/
# http://www.newsy.com/
# http://circa.com/
# http://circa.com/ cannot be scraped.
# http://www.pantagraph.com/
# http://www.liberalmountain.com/
# http://www.liberalmountain.com/ cannot be scraped.
# http://jointcenter.org/
# http://www.journalnow.com/
# http://cityandstateny.com/
# http://www.teapartypatriots.org/
# http://historynewsnetwork.org/
# http://defund.com/
# http://people.com/politics/
# http://www.oann.com/
# https://zcomm.org/zmag/
# http://theblacksphere.net/
# https://stocknewsusa.com
# http://www.cctv-america.com/
# http://www.hoover.org/
# http://www.learnliberty.org/
# http://www.learnliberty.org/ cannot be scraped.
# http://www.freepress.net/
# https://www.ciponline.org/
# https://www.ciponline.org/ cannot be scraped.
# http://www.ifyouonlynews.com/
# https://www.thenews.com.pk/
# https://www.wikitribune.com
# https://www.wikitribune.com cannot be scraped.
# https://www.earthmagazine.org/
# http://news.trust.org/
# https://www.libertynation.com
# http://www.eagletribune.com/
# http://russia-insider.com/en
# http://alphanewsmn.com/
# http://www.nola.com/#/0
# http://www.alhayat.com/
# http://www.roanoke.com/
# http://louderwithcrowder.com/
# https://www.theodysseyonline.com
# https://whowhatwhy.org/
# http://www.twincities.com/
# http://www.politico.com/
# https://knightstemplarinternational.com/
# https://knightstemplarinternational.com/ cannot be scraped.
# http://chronicle.su/
# http://www.columbiadailyherald.com/
# https://americanlookout.com/
# http://www.investors.com/
# http://www.investors.com/ cannot be scraped.
# http://www.cnsnews.com/
# https://www.thetimesherald.com
# http://ipolitics.ca/
# http://religionnews.com
# http://politicslive.net/
# http://politicslive.net/ cannot be scraped.
# https://www.marxist.com/
# https://www.marxist.com/ cannot be scraped.
# http://www.interpretermag.com/
# https://www.unwatch.org
# http://townhall.com/
# https://pjmedia.com/
# https://baptistnews.com/
# http://www.duffelblog.com/
# http://usadosenews.com/
# http://usadosenews.com/ cannot be scraped.
# http://www.omaha.com/
# http://economictimes.indiatimes.com/
# https://www.ndtv.com/
# https://lifehacker.com/
# http://www.mlive.com/
# http://www.mlive.com/ cannot be scraped.
# http://www.nationalmemo.com/
# http://www.nationalmemo.com/ cannot be scraped.
# http://projectveritas.com/
# http://taxfoundation.org/
# http://www.govexec.com/
# https://www.insidephilanthropy.com
# http://www.thejakartapost.com/
# https://conservative101.com/
# https://conservative101.com/ cannot be scraped.
# http://allnewspipeline.com/
# http://allnewspipeline.com/ cannot be scraped.
# http://www.washingtonexaminer.com/
# http://www.seattletimes.com/
# https://amgreatness.com
# https://amgreatness.com cannot be scraped.
# http://ibleedredwhiteblue.com/
# http://sonsoflibertymedia.com
# http://www.cbsnews.com/
# http://www.afr.com/
# http://chicago.suntimes.com/
# http://www.couriermail.com.au/
# http://globalnews.ca/
# https://www.americanprogress.org/
# https://nationalvanguard.org/
# http://www.theamericanconservative.com/
# http://eaglerising.com/
# http://erlc.com/
# https://www.defendevropa.org
# http://www.yesmagazine.org/
# http://stimson.org/
# http://www.peacock-panache.com
# http://host.madison.com/wsj/
# http://upr.org
# http://uproxx.com/
# http://sputniknews.com/
# http://wn.com/
# http://modernliberals.com/
# http://earthfirstjournal.org/
# http://www.libertyheadlines.com/
# https://freetelegraph.com/
# http://dandygoat.com/
# http://www.conservapedia.com/Main_Page
# http://www.strategic-culture.org/
# http://www.resourcegovernance.org/
# http://theamericanmirror.com/
# https://www.jacobinmag.com/
# http://www.ruthinstitute.org
# http://proudemocrat.com/
# http://proudemocrat.com/ cannot be scraped.
# http://fmobserver.com/
# http://www.betootaadvocate.com
# http://www.dailyrecord.co.uk/
# http://discovermagazine.com/
# http://talkingpointsmemo.com/
# http://www.birminghammail.co.uk
# https://americanconsequences.com
# http://sonorannews.com/
# http://mentalfloss.com/
# http://thefifthcolumnnews.com/
# http://www.informationliberation.com/
# https://www.dcreport.org/
# https://www.autostraddle.com/
# https://www.jns.org
# http://wgntv.com/
# https://bearingarms.com/
# http://americantruthseekers.com
# http://americantruthseekers.com cannot be scraped.
# http://themillenniumreport.com
# http://knoxreport.com/
# http://huzlers.com/
# https://mediaequalizer.com/
# http://www.thecanary.co/
# http://www.westernjournalism.com/
# http://www.workers.org/
# http://www.globalintegrity.org/
# http://harddawn.com/
# https://fedsoc.org/
# https://fedsoc.org/ cannot be scraped.
# http://politichicks.com/
# http://www.nextavenue.org/
# http://www.rappler.com/
# http://oppositionreport.com
# http://oppositionreport.com cannot be scraped.
# http://www.ejinsight.com/
# http://factbox.tv/
# http://factbox.tv/ cannot be scraped.
# https://www.avoiceformen.com/
# https://www.avoiceformen.com/ cannot be scraped.
# http://christwire.org/
# http://christwire.org/ cannot be scraped.
# http://www.futureinamerica.com/news
# http://www.futureinamerica.com/news cannot be scraped.
# http://newcenturytimes.com/
# http://newcenturytimes.com/ cannot be scraped.
# http://chaser.com.au
# http://www.financialpost.com/
# http://www.financialpost.com/ cannot be scraped.
# http://libertyhangout.org/
# http://www.newsday.com/
# https://www.psychologytoday.com/
# https://consortiumnews.com/
# http://usainfront.com
# http://usainfront.com cannot be scraped.
# http://www.conservativehq.com/
# http://rinf.com
# http://www.conservativedailynews.com/
# https://capitalresearch.org/
# https://infogalactic.com
# http://news.err.ee
# http://www.opslens.com/
# http://www.opslens.com/ cannot be scraped.
# http://vote.us.org/
# http://www.newsnow.co.uk/h/
# http://www.magapill.com
# http://www.themilitant.com/
# https://www.indymedia.org/or/index.shtml
# https://www.indymedia.org/or/index.shtml cannot be scraped.
# http://readersupportednews.org
# http://www.redstate.com/
# http://democratherald.com
# http://www.deccanherald.com/
# http://cowgernation.com/
# https://hillarydaily.com/
# http://www.freemedia.at/
# https://beinglibertarian.com/
# http://www.frontpagemag.com/
# http://americanindependent.com/
# http://www.curvemag.com
# http://ahtribune.com/
# http://www.nber.org/
# http://www.faithfamilyamerica.com
# http://www.faithfamilyamerica.com cannot be scraped.
# http://www.centerforinquiry.net/
# http://www.bjreview.com/
# http://www.bjreview.com/ cannot be scraped.
# https://www.tnonline.com
# http://www.elpasotimes.com/
# https://www.algemeiner.com/
# http://calgaryherald.com/
# http://calgaryherald.com/ cannot be scraped.
# https://feministfrequency.com/
# http://viralliberty.com/
# http://viralliberty.com/ cannot be scraped.
# http://dailysnark.com/
# http://eng.majalla.com/
# https://freedomhouse.org/
# http://newsblaze.com/
# http://votesmart.org/
# http://votesmart.org/ cannot be scraped.
# https://theintercept.com/
# http://evonomics.com/
# http://www.thenationalpatriot.com/
# http://www.torontosun.com/
# http://www.theunrealtimes.com/
# http://www.staresattheworld.com/
# https://youthradio.org/
# http://bluetribune.com/
# http://bluetribune.com/ cannot be scraped.
# http://notallowedto.com/
# http://worldpress.org/
# http://azdailysun.com
# http://newbostonpost.com
# http://thedcgazette.com/
# http://www.barenakedislam.com/
# http://twitchy.com/
# https://www.newyorker.com/humor/borowitz-report
# http://www.lbc.co.uk
# http://www.thenewamerican.com/
# http://www.rawstory.com/
# http://freakoutnation.com/
# http://freakoutnation.com/ cannot be scraped.
# http://www.smithsonianmag.com/
# http://www.unionleader.com/
# https://steadfastandloyal.com/
# http://theresurgent.com/
# http://www.cnntimes.online/
# http://www.cnntimes.online/ cannot be scraped.
# http://www.independentsentinel.com/
# http://100percentfedup.com/
# http://www.bullshido.net/
# http://www.tfp.org/
# http://www.lifenews.com/
# http://www.spiegel.de/international/
# http://www.sciencedirect.com/
# https://www.lewrockwell.com/
# http://gazette.com/
# http://www.patheos.com/
# http://girlsjustwannahaveguns.com/
# https://www.newsandgutsmedia.com/
# http://observeronline.news/
# http://observeronline.news/ cannot be scraped.
# http://crfb.org/
# https://www.stpete4peace.org/
# http://feministing.com/
# http://www.unz.com/
# https://globalvoices.org/
# http://www.dcstatesman.com/
# http://www.thedailyliberator.com/
# http://www.nationalreview.com/
# http://www.theburningspear.com/
# http://www.pacificpundit.com/
# https://theredshtick.com/
# http://politicaldig.com/
# https://www.memri.org/
# http://www.tvw.org/
# http://www.dailytarheel.com/
# http://lexingtoninstitute.org/
# http://www.kmov.com/
# http://www.nationaleconomicseditorial.com/
# https://www.middleeastmonitor.com/
# https://www.britannica.com/
# http://www.srnnews.com/
# http://www.srnnews.com/ cannot be scraped.
# http://www.dailytelegraph.com.au/
# https://www.foreignaffairs.com/
# http://cis.org/
# http://www.washingtonblade.com/
# https://canadiandimension.com/
# https://schmedium.org
# http://www.standard.net/
# https://www.change.org/
# http://www.democraticunderground.com/
# https://www.pastemagazine.com/
# https://www.texastribune.org/
# https://www.texastribune.org/ cannot be scraped.
# http://www.consnation.com/
# http://www.consnation.com/ cannot be scraped.
# http://www.ctvnews.ca/
# https://thewire.in/
# http://www.newser.com
# http://www.rep-am.com/
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-97d881e00a7a> in <module>()
# ----> 1 corp['article_raw'] = corp.source_url.apply(download_text)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4043             else:
#    4044                 values = self.astype(object).values
# -> 4045                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4046
#    4047         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-8-4c89dd8f7896> in download_text(url)
#       1 def download_text(url):
#       2
# ----> 3   site = newspaper.build(url)
#       4
#       5   ls = []
#
# /usr/local/lib/python3.6/dist-packages/newspaper/api.py in build(url, dry, config, **kwargs)
#      28     s = Source(url, config=config)
#      29     if not dry:
# ---> 30         s.build()
#      31     return s
#      32
#
# /usr/local/lib/python3.6/dist-packages/newspaper/source.py in build(self)
#      90         """
#      91         self.download()
# ---> 92         self.parse()
#      93
#      94         self.set_categories()
#
# /usr/local/lib/python3.6/dist-packages/newspaper/source.py in parse(self)
#     219         """
#     220         # TODO: This is a terrible idea, ill try to fix it when i'm more rested
# --> 221         self.doc = self.config.get_parser().fromstring(self.html)
#     222         if self.doc is None:
#     223             log.warning('Source %s parse error.' % self.url)
#
# /usr/local/lib/python3.6/dist-packages/newspaper/parsers.py in fromstring(cls, html)
#      59     @classmethod
#      60     def fromstring(cls, html):
# ---> 61         html = cls.get_unicode_html(html)
#      62         # Enclosed in a `try` to prevent bringing the entire library
#      63         # down due to one article (out of potentially many in a `Source`)
#
# /usr/local/lib/python3.6/dist-packages/newspaper/parsers.py in get_unicode_html(cls, html)
#      53             raise Exception(
#      54                 'Failed to detect encoding of article HTML, tried: %s' %
# ---> 55                 ', '.join(converted.tried_encodings))
#      56         html = converted.unicode_markup
#      57         return html
#
# TypeError: sequence item 0: expected str instance, tuple found

# %%
res = corp.to_csv('corpus_scraped_text.csv', index = False)

# %% [markdown]
# ### Further refinements
# - scrape websites for sample $(n = 5)$ articles per news source and vectorize text to create our own body of corpus
# - define a pipeline where we utilize logistic --> PCA/SVM --> PCA/Naive Bayes and compare results
# - introduce k-fold cross-validation

# %% [markdown]
# ## Tests

# %%
test_df = corp.sample(10)

# %%
test_df = test_df.dropna().reset_index(drop = True)

# %%
test_df = test_df.dropna().reset_index(drop = True)

test_df.article_raw

cols = ['article_1','article_2','article_3','article_4','article_5']

articles = pd.DataFrame(test_df.article_raw.tolist(), columns = cols)

pd.concat([test_df, articles], axis = 1)

# %%
dtest_df['articles'] = test_df.source_url.apply(download_text)
# Out:
# http://www.voanews.com/
# http://grist.org/
# http://lexingtoninstitute.org/
# http://thedcgazette.com/
# https://photographyisnotacrime.com/
# https://photographyisnotacrime.com/ cannot be scraped.
# http://liberaldarkness.com/
# https://www.cpj.org/
# https://theredshtick.com/
# http://vidmax.com/
# http://politichicks.com/

# %%
articles = test_df[['source_url', 'articles']].reset_index(drop = True)
test_df2 = test_df.drop(columns = ('articles')).reset_index(drop = True)

# %%
articles.articles
# Out:
# 0    [The Game Room\n\nWinners and almost winners t...
# 1    [a sign of relief Trump signs a relief bill co...
# 2    [Should an enemy submarine surface well beyond...
# 3    [On Wednesday night Speaker Nancy Pelosi attac...
# 4                                                 None
# 5    [Brock Turner has it coming to him for the wro...
# 6    [CPJ joins call for UN Security Council to act...
# 7    [Radio Stations Pull “All I Want for Christmas...
# 8                                             [, , , ]
# 9    [If you were running for President and you had...
# Name: articles, dtype: object

# %% [markdown]
# ## Extract articles, merge, and save

# %%
corp = corp.dropna().reset_index(drop = True)

corp.article_raw

cols = ['article_1','article_2','article_3','article_4','article_5']

articles = pd.DataFrame(corp.article_raw.tolist(), columns = cols)

test_corpus = pd.concat([corp, articles], axis = 1)

# %%
fs = test_corpus.to_csv('corpus_full_text_v2.csv', index = False)
